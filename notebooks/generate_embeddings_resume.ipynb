# %%
def remove_escape_characters(text: str) -> str:
    return text.replace("\n", " ").replace("·", "")

# %%
import os
from langchain_community.document_loaders import PyPDFLoader

RESUME_FOLDER_PATH = "../data/resumes"

# Step 1: Read documents
resume_docs = []
for filename in os.listdir(RESUME_FOLDER_PATH):
    if filename.endswith("pdf"):
        filepath = os.path.join(RESUME_FOLDER_PATH, filename)
        loader = PyPDFLoader(filepath)
        async for page in loader.alazy_load():
            page.page_content = remove_escape_characters(page.page_content)
            resume_docs.append(page)

resume_docs
# Out:
# [Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content="Shah Rukh Khan   Software Engineer   Mumbai, India    (123) 456-789    yourname@resumeworded.com    linkedin.com/in/your-profile    EXPERIENCE   Google February 2019 - Present   Software Engineer II   Successfully migrated business application to the Cloud, reducing operational cost by 30% and increasing system performance   Implemented microservices architecture, enhancing system scalability and reliability by 40%   Reduced time to fix bugs by 25% through effective use of test-driven development and continuous  integration strategies   Simplified and undated codebase, increasing software efficiency and readability by 35%   Optimized service by integrating Machine Learning models, boosting customer satisfaction by 15%   Resume Worded June 2016 - January 2019   Software Engineer   Built a secure data storage system, facilitating a 20% increase in system load capacity   Developed a scalable application using Python and C++ that increased user data processing by 30%   Overhauled existing software architecture, leading to 45% decrease in system downtimes   Coached.com August 2014 - May 2016   Junior Software Engineer   Implemented a task queuing system, increasing system tenfold   Developed user-friendly interfaces using J2EE and JavaScript frameworks, improving user experience  and increasing system efficiency by 20%   Automated database backup processes, significantly reducing data loss   IBM June 2013 - July 2014   Intern - Information Systems   Upgraded company's legacy codebase, reducing system errors by 15%   Performed thorough testing, including integration testing, unit testing, and test automation, reducing  system bugs by 20%   EDUCATION   Resume Worded Academic Center May 2014   Master of Science in Computer Science   Specialized in Distributed Systems   Thesis: Scalability Challenges in Cloud Computing Environments   Resume Worded University June 2013   Bachelor of Science in Software Engineering   Summa Cum Laude, GPA: 3.9/4.0   Part-time coursework while interning at IBM   SKILLS   Programming Languages: Python (Advanced), Java (Advanced), C++ (Intermediate), JavaScript  (Intermediate), SQL (Advanced), Ruby (Basic)   Web Technologies: HTML5, CSS3, React.js, Node.js, Angular, RESTful APIs, JSON, AJAX   Databases & Cloud: MySQL, PostgreSQL, MongoDB, AWS (Amazon Web Services), Microsoft Azure,  Google Cloud Platform   Tools & Platforms: Git, Docker, Kubernetes, Jenkins, JIRA, Agile Methodology, Scrum   OTHER   Certifications: Oracle Certified Professional Java SE 8 Programmer (2017), AWS Certified Solutions  Architect (2019)   Publications: Contributing Author of 'Efficient Code: The Handbook' (2018), Presented at the International Developers Conference (2020)   Awards: Google's Peak Performance Award (2020), Resume Worded Tech Innovator of the Year (2017)   Professional Membership: Association for Computing Machinery (ACM), IEEE Computer Society     "),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Liam Hawthorne   Florida      (736) 482-1957      liam@hawthorne.com      linkedin.com/in/liam-hawthorne   Highly skilled Senior Accountant with a proven track record in implementing financial systems and  strategies that enhance accuracy, efficiency, and profitability. With experience in leading high-performing  teams, I have successfully reduced operational costs by 15% and improved revenue projections by 30%.  My expertise in ensuring regulatory compliance, streamlining reporting processes, and aligning financial  planning with strategic goals positions me to significantly contribute to the financial success of my next  organization.   CAREER EXPERIENCE   Senior Accountant 01/2024 ± Present   Quantum Ledger Solutions     Orchestrated the implementation of a new financial forecasting model, improving the accuracy of  revenue projections by 30% and enabling more informed strategic decision-making.     Supervised a team of 7 accountants, fostering a high-performance culture that reduced month-end  close times by 20% and improved the accuracy of financial reporting.     Championed a company-wide cost reduction initiative, identifying inefficiencies and implementing  changes that resulted in a 15% decrease in operational costs.   Financial Analyst 03/2023 ± 12/2023   Meridian Financial Advisors     Managed the preparation and submission of quarterly and annual tax filings, ensuring 100% compliance with federal and state regulations and avoiding potential penalties.     Implemented a new financial reporting system, streamlining the process and reducing the time taken to  generate reports by 35%.     Conducted in-depth financial analysis for key business units, providing insights that contributed to a  10% increase in profitability.   Junior Accountant 11/2021 ± 03/2023   Catalyst Investment Group     Played a pivotal role in the successful completion of an external audit, coordinating with auditors and  providing necessary documentation, resulting in a clean audit report.     Developed and maintained a robust system of internal controls, significantly reducing the risk of  financial misstatement and enhancing the integrity of financial data.     Assisted in the development of annual budgets, incorporating strategic goals and objectives to align  financial planning with company vision.   SKILLS     Financial Forecasting     Team Leadership and Supervision     Cost Reduction and Efficiency Improvement     Tax Preparation and Compliance     Financial Reporting     Financial Analysis     Audit Coordination     Internal Controls Development     Budget Development     Strategic Financial Planning   EDUCATION   Bachelor of Science in Accounting   University of Richmond   2014-2018   Richmond, VA  '),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 1}, page_content='CERTIFICATIONS   Certified Financial Services Auditor (CFSA)   04/2024   Institute of Internal Auditors (IIA)   Certified Fraud Examiner (CFE)   04/2023   Association of Certified Fraud Examiners (ACFE)   Certified Information Systems Auditor (CISA)   04/2023   Information Systems Audit and Control Association (ISACA)     '),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='JOHN DOE   1374 Cleveland Avenue, Washington DC 20047   (202) 074-1701   John.doe@gmail.com      Accounts Payable Specialist with 6+ years of experience driving smooth and efficient functions of  accounts payable. Proven track record in managing full-cycle accounts payable, improving accuracy,  verifying vendor invoices, and ensuring timely payments.      PROFESSIONAL EXPERIENCE      THE WASHINGTON POST   Accounts Payable Specialist Washington, DC   September 2020±Present     Manage full-cycle accounts payable, including receiving, processing, and verifying 1,300+ invoices per  month, averaging $7.8 million    Reconcile processed invoices to ensure 100% accuracy by verifying entries and comparing system  reports to balances    Reduced vendor reclassification 50%, ensuring the accuracy of vendor coding and accounts payable  batch output    Slashed costs by 25% by finding new vendors and overseeing their integration during the acquisition  process    Distribute payments to vendors, monitoring discount opportunities and resolving discrepancies in  purchase orders, invoices, and payments      AMERICAN UNIVERSITY   Accounts Payable Coordinator Washington, DC   July 2017±August 2020    Processed 1,500+ invoices per month with 99.9% accuracy    Redesigned accounts payable forms for better understanding among the university community    Slashed late fees from 30% to 5% and enhanced productivity by 47% by redesigning and implementing  an improved AP approval process    Implemented new AP procedures that reduced costs by $30K annually    Trained 20+ new employees on AP procedures and processes      EDUCATION      UNIVERSITY OF MARYLAND UNIVERSITY COLLEGE   Bachelor of Science in Business Administration, Accounting    Honors: cum laude (GPA: 3.8/4.0) College Park, MD   May 2016      ADDITIONAL SKILLS       Expert in Microsoft Office (Word, Access, Excel, Outlook), QuickBooks Pro    Bilingual in English and Spanish     '),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='GIULIA GONZALEZ   PYTHON DEVELOPER   CONTACT   ggonzalez@email.com   (123) 456-7890   Detroit, MI   LinkedIn   Github   EDUCATION   M.S.   Computer Science   University of Chicago   2014 - 2016   Chicago, IL   B.S.   Computer Science   University of Pittsburgh   2010 - 2014   Pittsburgh, PA   SKILLS   HTML/ CSS   SQL (PostgreSQL, Oracle)   JavaScript (Angular)   Python (Django)   REST APIs (GraphQL)   AWS (Redshift, S3)   Git   WORK EXPERIENCE   Python Developer   DoorDash   September 2017 - current / Detroit, MI   Worked on building new Angular components for the customer-facing   web app, which improved the time on page for the average user by 2   minutes   Collaborated with an agile team of 6, and helped prioritize and scope   feature requests to ensure that the biggest impact features were   worked on first   Built extensive test coverage for all new features, which reduced the   number of customer complaints by 23%   Acquired and ingested data to build and maintain data pipelines that   led to discovering an opportunity for a new site feature, boosting   revenue by 6%   Communicated with internal teams and stakeholders, working to   determine solutions for the user experience   Python Developer Intern   Knewton   April 2016 - April 2017 / Chicago, IL   Worked alongside another developer to implement RESTful APIs in   Django that enabled internal analytics team to increase reporting   speed by 24%   Using Selenium, built out a unit testing infrastructure for a client web   application that reduced the number of bugs reported by the client by   11% month over month   Provided project updates to leadership team of 3, and offered   recommendations for design  '),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 1}, page_content='Diagnosed issues causing slow speeds in applications, and   documented the process to making the database query system more   robust   Participated in writing scalable code with a team of 4 interns and 1   developer for applications for a math course  ')]

# %%
# Step 2: Make chunks with documents
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=100, 
    chunk_overlap = 60,
    length_function = len,
)

resume_chunks = splitter.split_documents(resume_docs)
resume_chunks
# Out:
# [Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Shah Rukh Khan   Software Engineer   Mumbai, India    (123) 456-789    yourname@resumeworded.com'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='India    (123) 456-789    yourname@resumeworded.com    linkedin.com/in/your-profile    EXPERIENCE'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='linkedin.com/in/your-profile    EXPERIENCE   Google February 2019 - Present   Software Engineer'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Google February 2019 - Present   Software Engineer II   Successfully migrated business'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Software Engineer II   Successfully migrated business application to the Cloud, reducing'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='migrated business application to the Cloud, reducing operational cost by 30% and increasing system'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='reducing operational cost by 30% and increasing system performance   Implemented microservices'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='increasing system performance   Implemented microservices architecture, enhancing system'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Implemented microservices architecture, enhancing system scalability and reliability by 40%'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='enhancing system scalability and reliability by 40%   Reduced time to fix bugs by 25% through'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='by 40%   Reduced time to fix bugs by 25% through effective use of test-driven development and'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='by 25% through effective use of test-driven development and continuous  integration strategies'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='development and continuous  integration strategies   Simplified and undated codebase, increasing'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='strategies   Simplified and undated codebase, increasing software efficiency and readability by 35%'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='increasing software efficiency and readability by 35%   Optimized service by integrating Machine'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='by 35%   Optimized service by integrating Machine Learning models, boosting customer satisfaction'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Machine Learning models, boosting customer satisfaction by 15%   Resume Worded June 2016 - January'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='satisfaction by 15%   Resume Worded June 2016 - January 2019   Software Engineer   Built a secure'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='2016 - January 2019   Software Engineer   Built a secure data storage system, facilitating a 20%'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Built a secure data storage system, facilitating a 20% increase in system load capacity'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='facilitating a 20% increase in system load capacity   Developed a scalable application using Python'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='capacity   Developed a scalable application using Python and C++ that increased user data'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='application using Python and C++ that increased user data processing by 30%   Overhauled existing'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='increased user data processing by 30%   Overhauled existing software architecture, leading to 45%'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Overhauled existing software architecture, leading to 45% decrease in system downtimes'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='architecture, leading to 45% decrease in system downtimes   Coached.com August 2014 - May 2016'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='in system downtimes   Coached.com August 2014 - May 2016   Junior Software Engineer   Implemented a'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='2014 - May 2016   Junior Software Engineer   Implemented a task queuing system, increasing system'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Implemented a task queuing system, increasing system tenfold   Developed user-friendly interfaces'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='system tenfold   Developed user-friendly interfaces using J2EE and JavaScript frameworks, improving'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='interfaces using J2EE and JavaScript frameworks, improving user experience  and increasing system'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='improving user experience  and increasing system efficiency by 20%   Automated database backup'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='system efficiency by 20%   Automated database backup processes, significantly reducing data loss'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='backup processes, significantly reducing data loss   IBM June 2013 - July 2014   Intern -'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content="reducing data loss   IBM June 2013 - July 2014   Intern - Information Systems   Upgraded company's"),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content="2014   Intern - Information Systems   Upgraded company's legacy codebase, reducing system errors by"),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content="company's legacy codebase, reducing system errors by 15%   Performed thorough testing, including"),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='errors by 15%   Performed thorough testing, including integration testing, unit testing, and test'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='including integration testing, unit testing, and test automation, reducing  system bugs by 20%'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='and test automation, reducing  system bugs by 20%   EDUCATION   Resume Worded Academic Center May'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='bugs by 20%   EDUCATION   Resume Worded Academic Center May 2014   Master of Science in Computer'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Academic Center May 2014   Master of Science in Computer Science   Specialized in Distributed'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='of Science in Computer Science   Specialized in Distributed Systems   Thesis: Scalability'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Specialized in Distributed Systems   Thesis: Scalability Challenges in Cloud Computing'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Systems   Thesis: Scalability Challenges in Cloud Computing Environments   Resume Worded University'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='in Cloud Computing Environments   Resume Worded University June 2013   Bachelor of Science in'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Resume Worded University June 2013   Bachelor of Science in Software Engineering   Summa Cum Laude,'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='of Science in Software Engineering   Summa Cum Laude, GPA: 3.9/4.0   Part-time coursework while'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Summa Cum Laude, GPA: 3.9/4.0   Part-time coursework while interning at IBM   SKILLS   Programming'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='coursework while interning at IBM   SKILLS   Programming Languages: Python (Advanced), Java'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='SKILLS   Programming Languages: Python (Advanced), Java (Advanced), C++ (Intermediate),'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Python (Advanced), Java (Advanced), C++ (Intermediate), JavaScript  (Intermediate), SQL (Advanced),'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='(Intermediate), JavaScript  (Intermediate), SQL (Advanced), Ruby (Basic)   Web Technologies: HTML5,'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='SQL (Advanced), Ruby (Basic)   Web Technologies: HTML5, CSS3, React.js, Node.js, Angular, RESTful'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='HTML5, CSS3, React.js, Node.js, Angular, RESTful APIs, JSON, AJAX   Databases & Cloud: MySQL,'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='RESTful APIs, JSON, AJAX   Databases & Cloud: MySQL, PostgreSQL, MongoDB, AWS (Amazon Web'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='& Cloud: MySQL, PostgreSQL, MongoDB, AWS (Amazon Web Services), Microsoft Azure,  Google Cloud'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='AWS (Amazon Web Services), Microsoft Azure,  Google Cloud Platform   Tools & Platforms: Git,'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Azure,  Google Cloud Platform   Tools & Platforms: Git, Docker, Kubernetes, Jenkins, JIRA, Agile'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='& Platforms: Git, Docker, Kubernetes, Jenkins, JIRA, Agile Methodology, Scrum   OTHER'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Jenkins, JIRA, Agile Methodology, Scrum   OTHER   Certifications: Oracle Certified Professional'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='OTHER   Certifications: Oracle Certified Professional Java SE 8 Programmer (2017), AWS Certified'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Professional Java SE 8 Programmer (2017), AWS Certified Solutions  Architect (2019)   Publications:'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content="AWS Certified Solutions  Architect (2019)   Publications: Contributing Author of 'Efficient Code:"),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content="Publications: Contributing Author of 'Efficient Code: The Handbook' (2018), Presented at the"),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content="of 'Efficient Code: The Handbook' (2018), Presented at the International Developers Conference"),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content="Presented at the International Developers Conference (2020)   Awards: Google's Peak Performance"),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content="Conference (2020)   Awards: Google's Peak Performance Award (2020), Resume Worded Tech Innovator of"),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Performance Award (2020), Resume Worded Tech Innovator of the Year (2017)   Professional'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='Worded Tech Innovator of the Year (2017)   Professional Membership: Association for Computing'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='(2017)   Professional Membership: Association for Computing Machinery (ACM), IEEE Computer Society'),
#  Document(metadata={'source': '../data/resumes/resume-software-engg.pdf', 'page': 0}, page_content='for Computing Machinery (ACM), IEEE Computer Society'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Liam Hawthorne   Florida      (736) 482-1957      liam@hawthorne.com'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Florida      (736) 482-1957      liam@hawthorne.com      linkedin.com/in/liam-hawthorne   Highly'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='linkedin.com/in/liam-hawthorne   Highly skilled Senior Accountant with a proven track record'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Highly skilled Senior Accountant with a proven track record in implementing financial systems and'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='proven track record in implementing financial systems and  strategies that enhance accuracy,'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='financial systems and  strategies that enhance accuracy, efficiency, and profitability. With'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='that enhance accuracy, efficiency, and profitability. With experience in leading high-performing'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='profitability. With experience in leading high-performing  teams, I have successfully reduced'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='leading high-performing  teams, I have successfully reduced operational costs by 15% and improved'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='successfully reduced operational costs by 15% and improved revenue projections by 30%.  My'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='costs by 15% and improved revenue projections by 30%.  My expertise in ensuring regulatory'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='projections by 30%.  My expertise in ensuring regulatory compliance, streamlining reporting'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='in ensuring regulatory compliance, streamlining reporting processes, and aligning financial'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='streamlining reporting processes, and aligning financial  planning with strategic goals positions'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='aligning financial  planning with strategic goals positions me to significantly contribute to the'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='goals positions me to significantly contribute to the financial success of my next  organization.'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='to the financial success of my next  organization.   CAREER EXPERIENCE   Senior Accountant 01/2024'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='CAREER EXPERIENCE   Senior Accountant 01/2024 ± Present   Quantum Ledger Solutions'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Accountant 01/2024 ± Present   Quantum Ledger Solutions     Orchestrated the implementation of a'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Ledger Solutions     Orchestrated the implementation of a new financial forecasting model,'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='the implementation of a new financial forecasting model, improving the accuracy of  revenue'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='forecasting model, improving the accuracy of  revenue projections by 30% and enabling more informed'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='of  revenue projections by 30% and enabling more informed strategic decision-making.     Supervised'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='more informed strategic decision-making.     Supervised a team of 7 accountants, fostering a'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Supervised a team of 7 accountants, fostering a high-performance culture that reduced month-end'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='fostering a high-performance culture that reduced month-end  close times by 20% and improved the'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='that reduced month-end  close times by 20% and improved the accuracy of financial reporting.'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='20% and improved the accuracy of financial reporting.     Championed a company-wide cost reduction'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='reporting.     Championed a company-wide cost reduction initiative, identifying inefficiencies and'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='cost reduction initiative, identifying inefficiencies and implementing  changes that resulted in a'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='inefficiencies and implementing  changes that resulted in a 15% decrease in operational costs.'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='that resulted in a 15% decrease in operational costs.   Financial Analyst 03/2023 ± 12/2023'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='operational costs.   Financial Analyst 03/2023 ± 12/2023   Meridian Financial Advisors     Managed'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='03/2023 ± 12/2023   Meridian Financial Advisors     Managed the preparation and submission of'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Advisors     Managed the preparation and submission of quarterly and annual tax filings, ensuring'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='submission of quarterly and annual tax filings, ensuring 100% compliance with federal and state'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='filings, ensuring 100% compliance with federal and state regulations and avoiding potential'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='with federal and state regulations and avoiding potential penalties.     Implemented a new'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='and avoiding potential penalties.     Implemented a new financial reporting system, streamlining'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Implemented a new financial reporting system, streamlining the process and reducing the time taken'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='streamlining the process and reducing the time taken to  generate reports by 35%.     Conducted'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='the time taken to  generate reports by 35%.     Conducted in-depth financial analysis for key'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='by 35%.     Conducted in-depth financial analysis for key business units, providing insights that'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='analysis for key business units, providing insights that contributed to a  10% increase in'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='providing insights that contributed to a  10% increase in profitability.   Junior Accountant'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='to a  10% increase in profitability.   Junior Accountant 11/2021 ± 03/2023   Catalyst Investment'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Junior Accountant 11/2021 ± 03/2023   Catalyst Investment Group     Played a pivotal role in the'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Catalyst Investment Group     Played a pivotal role in the successful completion of an external'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='a pivotal role in the successful completion of an external audit, coordinating with auditors and'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='of an external audit, coordinating with auditors and  providing necessary documentation, resulting'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='auditors and  providing necessary documentation, resulting in a clean audit report.     Developed'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='resulting in a clean audit report.     Developed and maintained a robust system of internal'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Developed and maintained a robust system of internal controls, significantly reducing the risk'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='of internal controls, significantly reducing the risk of  financial misstatement and enhancing the'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='the risk of  financial misstatement and enhancing the integrity of financial data.     Assisted in'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='enhancing the integrity of financial data.     Assisted in the development of annual budgets,'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='data.     Assisted in the development of annual budgets, incorporating strategic goals and'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='of annual budgets, incorporating strategic goals and objectives to align  financial planning with'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='goals and objectives to align  financial planning with company vision.   SKILLS     Financial'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='planning with company vision.   SKILLS     Financial Forecasting     Team Leadership and'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='SKILLS     Financial Forecasting     Team Leadership and Supervision     Cost Reduction and'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Team Leadership and Supervision     Cost Reduction and Efficiency Improvement     Tax'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Cost Reduction and Efficiency Improvement     Tax Preparation and Compliance     Financial'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Tax Preparation and Compliance     Financial Reporting     Financial Analysis     Audit'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Financial Reporting     Financial Analysis     Audit Coordination     Internal Controls'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Analysis     Audit Coordination     Internal Controls Development     Budget Development'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Internal Controls Development     Budget Development     Strategic Financial Planning'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Budget Development     Strategic Financial Planning   EDUCATION   Bachelor of Science in'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='Financial Planning   EDUCATION   Bachelor of Science in Accounting   University of Richmond'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 0}, page_content='of Science in Accounting   University of Richmond   2014-2018   Richmond, VA'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 1}, page_content='CERTIFICATIONS   Certified Financial Services Auditor (CFSA)   04/2024   Institute of Internal'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 1}, page_content='Services Auditor (CFSA)   04/2024   Institute of Internal Auditors (IIA)   Certified Fraud Examiner'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 1}, page_content='of Internal Auditors (IIA)   Certified Fraud Examiner (CFE)   04/2023   Association of Certified'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 1}, page_content='Fraud Examiner (CFE)   04/2023   Association of Certified Fraud Examiners (ACFE)   Certified'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 1}, page_content='Association of Certified Fraud Examiners (ACFE)   Certified Information Systems Auditor (CISA)'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 1}, page_content='(ACFE)   Certified Information Systems Auditor (CISA)   04/2023   Information Systems Audit and'),
#  Document(metadata={'source': '../data/resumes/resume-senior-accounting.pdf', 'page': 1}, page_content='Auditor (CISA)   04/2023   Information Systems Audit and Control Association (ISACA)'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='JOHN DOE   1374 Cleveland Avenue, Washington DC 20047   (202) 074-1701   John.doe@gmail.com'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='DC 20047   (202) 074-1701   John.doe@gmail.com      Accounts Payable Specialist with 6+ years of'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='Accounts Payable Specialist with 6+ years of experience driving smooth and efficient functions'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='years of experience driving smooth and efficient functions of  accounts payable. Proven track'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='and efficient functions of  accounts payable. Proven track record in managing full-cycle accounts'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='Proven track record in managing full-cycle accounts payable, improving accuracy,  verifying vendor'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='accounts payable, improving accuracy,  verifying vendor invoices, and ensuring timely payments.'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='vendor invoices, and ensuring timely payments.      PROFESSIONAL EXPERIENCE      THE WASHINGTON'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='payments.      PROFESSIONAL EXPERIENCE      THE WASHINGTON POST   Accounts Payable Specialist'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='THE WASHINGTON POST   Accounts Payable Specialist Washington, DC   September 2020±Present'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='Specialist Washington, DC   September 2020±Present     Manage full-cycle accounts payable,'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='2020±Present     Manage full-cycle accounts payable, including receiving, processing, and verifying'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='payable, including receiving, processing, and verifying 1,300+ invoices per  month, averaging $7.8'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='and verifying 1,300+ invoices per  month, averaging $7.8 million    Reconcile processed invoices to'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='averaging $7.8 million    Reconcile processed invoices to ensure 100% accuracy by verifying entries'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='invoices to ensure 100% accuracy by verifying entries and comparing system  reports to balances'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='entries and comparing system  reports to balances    Reduced vendor reclassification 50%, ensuring'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='balances    Reduced vendor reclassification 50%, ensuring the accuracy of vendor coding and'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='50%, ensuring the accuracy of vendor coding and accounts payable  batch output    Slashed costs by'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='and accounts payable  batch output    Slashed costs by 25% by finding new vendors and overseeing'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='Slashed costs by 25% by finding new vendors and overseeing their integration during the'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='new vendors and overseeing their integration during the acquisition  process    Distribute payments'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='during the acquisition  process    Distribute payments to vendors, monitoring discount'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='Distribute payments to vendors, monitoring discount opportunities and resolving discrepancies in'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='discount opportunities and resolving discrepancies in  purchase orders, invoices, and payments'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='in  purchase orders, invoices, and payments      AMERICAN UNIVERSITY   Accounts Payable Coordinator'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='AMERICAN UNIVERSITY   Accounts Payable Coordinator Washington, DC   July 2017±August 2020'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='Coordinator Washington, DC   July 2017±August 2020    Processed 1,500+ invoices per month with'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='2020    Processed 1,500+ invoices per month with 99.9% accuracy    Redesigned accounts payable'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='month with 99.9% accuracy    Redesigned accounts payable forms for better understanding among the'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='accounts payable forms for better understanding among the university community    Slashed late fees'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='among the university community    Slashed late fees from 30% to 5% and enhanced productivity by 47%'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='late fees from 30% to 5% and enhanced productivity by 47% by redesigning and implementing  an'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='productivity by 47% by redesigning and implementing  an improved AP approval process    Implemented'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='an improved AP approval process    Implemented new AP procedures that reduced costs by $30K'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='Implemented new AP procedures that reduced costs by $30K annually    Trained 20+ new employees'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='reduced costs by $30K annually    Trained 20+ new employees on AP procedures and processes'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='20+ new employees on AP procedures and processes      EDUCATION      UNIVERSITY OF MARYLAND'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='and processes      EDUCATION      UNIVERSITY OF MARYLAND UNIVERSITY COLLEGE   Bachelor of Science'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='OF MARYLAND UNIVERSITY COLLEGE   Bachelor of Science in Business Administration, Accounting'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='of Science in Business Administration, Accounting    Honors: cum laude (GPA: 3.8/4.0) College Park,'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='Honors: cum laude (GPA: 3.8/4.0) College Park, MD   May 2016      ADDITIONAL SKILLS       Expert'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='Park, MD   May 2016      ADDITIONAL SKILLS       Expert in Microsoft Office (Word, Access, Excel,'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='Expert in Microsoft Office (Word, Access, Excel, Outlook), QuickBooks Pro    Bilingual in'),
#  Document(metadata={'source': '../data/resumes/resume-accounts-payable.pdf', 'page': 0}, page_content='Access, Excel, Outlook), QuickBooks Pro    Bilingual in English and Spanish'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='GIULIA GONZALEZ   PYTHON DEVELOPER   CONTACT   ggonzalez@email.com   (123) 456-7890   Detroit, MI'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='ggonzalez@email.com   (123) 456-7890   Detroit, MI   LinkedIn   Github   EDUCATION   M.S.'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='Detroit, MI   LinkedIn   Github   EDUCATION   M.S.   Computer Science   University of Chicago'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='M.S.   Computer Science   University of Chicago   2014 - 2016   Chicago, IL   B.S.   Computer'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='of Chicago   2014 - 2016   Chicago, IL   B.S.   Computer Science   University of Pittsburgh   2010'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='B.S.   Computer Science   University of Pittsburgh   2010 - 2014   Pittsburgh, PA   SKILLS'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='of Pittsburgh   2010 - 2014   Pittsburgh, PA   SKILLS   HTML/ CSS   SQL (PostgreSQL, Oracle)'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='PA   SKILLS   HTML/ CSS   SQL (PostgreSQL, Oracle)   JavaScript (Angular)   Python (Django)   REST'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='Oracle)   JavaScript (Angular)   Python (Django)   REST APIs (GraphQL)   AWS (Redshift, S3)   Git'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='(Django)   REST APIs (GraphQL)   AWS (Redshift, S3)   Git   WORK EXPERIENCE   Python Developer'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='(Redshift, S3)   Git   WORK EXPERIENCE   Python Developer   DoorDash   September 2017 - current /'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='Python Developer   DoorDash   September 2017 - current / Detroit, MI   Worked on building new'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='2017 - current / Detroit, MI   Worked on building new Angular components for the customer-facing'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='building new Angular components for the customer-facing   web app, which improved the time on page'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='customer-facing   web app, which improved the time on page for the average user by 2   minutes'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='the time on page for the average user by 2   minutes   Collaborated with an agile team of 6, and'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='by 2   minutes   Collaborated with an agile team of 6, and helped prioritize and scope   feature'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='agile team of 6, and helped prioritize and scope   feature requests to ensure that the biggest'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='and scope   feature requests to ensure that the biggest impact features were   worked on first'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='that the biggest impact features were   worked on first   Built extensive test coverage for all new'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='worked on first   Built extensive test coverage for all new features, which reduced the   number of'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='for all new features, which reduced the   number of customer complaints by 23%   Acquired and'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='the   number of customer complaints by 23%   Acquired and ingested data to build and maintain data'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='23%   Acquired and ingested data to build and maintain data pipelines that   led to discovering an'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='and maintain data pipelines that   led to discovering an opportunity for a new site feature,'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='led to discovering an opportunity for a new site feature, boosting   revenue by 6%   Communicated'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='a new site feature, boosting   revenue by 6%   Communicated with internal teams and stakeholders,'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='by 6%   Communicated with internal teams and stakeholders, working to   determine solutions for the'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='and stakeholders, working to   determine solutions for the user experience   Python Developer'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='solutions for the user experience   Python Developer Intern   Knewton   April 2016 - April 2017 /'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='Developer Intern   Knewton   April 2016 - April 2017 / Chicago, IL   Worked alongside another'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='2016 - April 2017 / Chicago, IL   Worked alongside another developer to implement RESTful APIs in'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='alongside another developer to implement RESTful APIs in   Django that enabled internal analytics'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='RESTful APIs in   Django that enabled internal analytics team to increase reporting   speed by 24%'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='analytics team to increase reporting   speed by 24%   Using Selenium, built out a unit testing'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='speed by 24%   Using Selenium, built out a unit testing infrastructure for a client web'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='built out a unit testing infrastructure for a client web   application that reduced the number of'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='for a client web   application that reduced the number of bugs reported by the client by   11%'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='reduced the number of bugs reported by the client by   11% month over month   Provided project'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='by the client by   11% month over month   Provided project updates to leadership team of 3, and'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 0}, page_content='Provided project updates to leadership team of 3, and offered   recommendations for design'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 1}, page_content='Diagnosed issues causing slow speeds in applications, and   documented the process to making the'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 1}, page_content='in applications, and   documented the process to making the database query system more   robust'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 1}, page_content='process to making the database query system more   robust   Participated in writing scalable code'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 1}, page_content='more   robust   Participated in writing scalable code with a team of 4 interns and 1   developer'),
#  Document(metadata={'source': '../data/resumes/resume-senior-python-dev.pdf', 'page': 1}, page_content='scalable code with a team of 4 interns and 1   developer for applications for a math course')]

# %%
# Step 3: Embed documents
from langchain_huggingface import HuggingFaceEmbeddings
from sentence_transformers import SentenceTransformer



def get_embedding_function():
    embedding_model_path = "models--sentence-transformers--all-mpnet-base-v2"

    if not os.path.exists(embedding_model_path):
        embeddings_model = SentenceTransformer("sentence-transformers/all-mpnet-base-v2", cache_folder=".")
    else:
        pass
    
    # Load the model using HuggingFaceEmbeddings
    try:
        embeddings_model = HuggingFaceEmbeddings(model_name=embedding_model_path,
                                                model_kwargs={'device': 'cuda',},
                                                encode_kwargs={'normalize_embeddings': True})
    except OSError as e:
        print(f"Error loading model: {e}")
        # Handle the error appropriately, e.g., return None or raise a custom exception
        return None
    return embeddings_model

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F

#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

def get_sentence_embeddings(input_sentences: list[str]):
    # Sentences we want sentence embeddings for
    sentences = input_sentences

    # Load model from HuggingFace Hub
    tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-mpnet-base-v2')
    model = AutoModel.from_pretrained('sentence-transformers/all-mpnet-base-v2')

    # Tokenize sentences
    encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

    # Compute token embeddings
    with torch.no_grad():
        model_output = model(**encoded_input)

    # Perform pooling
    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

    # Normalize embeddings
    sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

    return sentence_embeddings

ex = get_sentence_embeddings(["My name is Harsha", "I am not a student"])
ex_1 = get_sentence_embeddings(["My name is Harsha"])
ex_2 = get_sentence_embeddings(["I am not a student"])

# %%
ex_c = torch.cat((ex_1, ex_2), dim=0)
ex_c.size()
# Out:
# torch.Size([2, 768])

# %%
torch.equal(ex, ex_c)
# Out:
# False

# %%
torch.eq(ex, ex_c)
# Out:
# tensor([[False, False, False,  ..., False, False, False],
#         [False, False, False,  ...,  True, False, False]])

# %%
for chunk in resume_chunks:
    print(len(chunk.page_content))
# Out:
# 96
# 97
# 95
# 86
# 88
# 98
# 94
# 88
# 91
# 93
# 93
# 94
# 96
# 99
# 96
# 97
# 98
# 97
# 96
# 87
# 99
# 89
# 97
# 97
# 86
# 94
# 99
# 97
# 97
# 99
# 97
# 94
# 96
# 89
# 98
# 99
# 96
# 97
# 94
# 97
# 96
# 93
# 89
# 86
# 99
# 93
# 99
# 95
# 98
# 91
# 87
# 99
# 99
# 97
# 93
# 89
# 94
# 92
# 96
# 85
# 95
# 96
# 99
# 97
# 92
# 94
# 95
# 99
# 88
# 93
# 98
# 52
# 68
# 96
# 92
# 97
# 92
# 92
# 96
# 93
# 97
# 90
# 90
# 91
# 91
# 97
# 97
# 97
# 98
# 82
# 96
# 90
# 91
# 99
# 99
# 92
# 95
# 96
# 92
# 98
# 98
# 98
# 94
# 91
# 98
# 93
# 97
# 95
# 91
# 90
# 96
# 98
# 95
# 93
# 97
# 90
# 92
# 96
# 96
# 95
# 96
# 98
# 97
# 91
# 94
# 98
# 98
# 93
# 90
# 97
# 93
# 88
# 91
# 85
# 90
# 87
# 87
# 88
# 85
# 88
# 91
# 76
# 94
# 99
# 96
# 92
# 94
# 95
# 84
# 91
# 96
# 94
# 93
# 97
# 98
# 95
# 95
# 93
# 89
# 90
# 99
# 98
# 99
# 99
# 95
# 98
# 91
# 98
# 96
# 87
# 99
# 86
# 96
# 94
# 99
# 89
# 94
# 94
# 97
# 99
# 99
# 93
# 99
# 91
# 94
# 90
# 91
# 97
# 91
# 99
# 96
# 97
# 89
# 75
# 97
# 89
# 93
# 93
# 98
# 90
# 92
# 98
# 97
# 94
# 97
# 93
# 96
# 98
# 94
# 96
# 96
# 94
# 94
# 99
# 99
# 93
# 98
# 98
# 92
# 97
# 97
# 99
# 93
# 97
# 93
# 97
# 97
# 98
# 94
# 87
# 97
# 94
# 94
# 95
# 90
# 96
# 95
# 97
# 96
# 91
